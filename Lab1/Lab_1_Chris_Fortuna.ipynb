# %% [markdown]
# ## Chris Fortuna
# ## CS 501r Deep Learning
# ## 31 August, 2016
# ## Lab 1

# %%
import numpy as np
import scipy as scp
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from PIL import Image, ImageDraw

# %matplotlib inline

# %% [markdown]
# # Part 1

# %%
from io import BytesIO
import requests

url = 'http://lorempixel.com/512/288/cats'
response = requests.get(url)
img = Image.open(BytesIO(response.content))
draw = ImageDraw.Draw(img)

# draw.arc([(np.random.rand(),np.random.rand()),(np.random.rand(),np.random.rand())], 360 * np.random.rand(), 360 * np.random.rand(), fill = 250 * np.random.rand())


for x in range(50):
    draw.pieslice([512 * np.random.rand(), 288 * np.random.rand(), 512 * np.random.rand(), 288 * np.random.rand()], int(360 * np.random.rand()), int(360 * np.random.rand()), fill=(int(256 * np.random.rand()),int(256 * np.random.rand()),int(256 * np.random.rand())))


img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x288 at 0x7FDB2AC82710>

# %%
response = requests.get(url)
img = Image.open(BytesIO(response.content))
draw = ImageDraw.Draw(img)

# draw.arc([(np.random.rand(),np.random.rand()),(np.random.rand(),np.random.rand())], 360 * np.random.rand(), 360 * np.random.rand(), fill = 250 * np.random.rand())


for x in range(50):
    draw.pieslice([512 * np.random.rand(), 288 * np.random.rand(), 512 * np.random.rand(), 288 * np.random.rand()], int(360 * np.random.rand()), int(360 * np.random.rand()), fill=(int(256 * np.random.rand()),int(256 * np.random.rand()),int(256 * np.random.rand())))


img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x288 at 0x7FDB2AC82DA0>

# %%
response = requests.get(url)
img = Image.open(BytesIO(response.content))
draw = ImageDraw.Draw(img)

# draw.arc([(np.random.rand(),np.random.rand()),(np.random.rand(),np.random.rand())], 360 * np.random.rand(), 360 * np.random.rand(), fill = 250 * np.random.rand())


for x in range(50):
    draw.pieslice([512 * np.random.rand(), 288 * np.random.rand(), 512 * np.random.rand(), 288 * np.random.rand()], int(360 * np.random.rand()), int(360 * np.random.rand()), fill=(int(256 * np.random.rand()),int(256 * np.random.rand()),int(256 * np.random.rand())))


img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x288 at 0x7FDB2C6E37B8>

# %%
response = requests.get(url)
img = Image.open(BytesIO(response.content))
draw = ImageDraw.Draw(img)

# draw.arc([(np.random.rand(),np.random.rand()),(np.random.rand(),np.random.rand())], 360 * np.random.rand(), 360 * np.random.rand(), fill = 250 * np.random.rand())


for x in range(50):
    draw.pieslice([512 * np.random.rand(), 288 * np.random.rand(), 512 * np.random.rand(), 288 * np.random.rand()], int(360 * np.random.rand()), int(360 * np.random.rand()), fill=(int(256 * np.random.rand()),int(256 * np.random.rand()),int(256 * np.random.rand())))


img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x288 at 0x7FDB2AC87CC0>

# %%
response = requests.get(url)
img = Image.open(BytesIO(response.content))
draw = ImageDraw.Draw(img)

# draw.arc([(np.random.rand(),np.random.rand()),(np.random.rand(),np.random.rand())], 360 * np.random.rand(), 360 * np.random.rand(), fill = 250 * np.random.rand())


for x in range(50):
    draw.pieslice([512 * np.random.rand(), 288 * np.random.rand(), 512 * np.random.rand(), 288 * np.random.rand()], int(360 * np.random.rand()), int(360 * np.random.rand()), fill=(int(256 * np.random.rand()),int(256 * np.random.rand()),int(256 * np.random.rand())))


img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x288 at 0x7FDB2AC8BE10>

# %% [markdown]
# # Part 2

# %%
from IPython.display import Image
Image(filename='tf_playground.png')
